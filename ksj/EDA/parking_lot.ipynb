# %%
import pandas as pd

# %%
df = pd.read_csv('./data/서울시 공영주차장 안내 정보.csv', encoding = 'cp949')
df.head()
# Out:
#     주차장코드              주차장명              주소 주차장 종류 주차장 종류명  운영구분  \
# 0   74588       가오천 노상공영(구)  강북구 수유동 181-40     NS  노상 주차장     3
# 1   75432      아카데미 노상공영(구)  강북구 수유동 535-76     NS  노상 주차장     3
# 2   79957       빨래골 노상공영(구)   강북구 수유동 49-27     NS  노상 주차장     3
# 3  119824  여의도공원앞1 노상주차장(구)  영등포구 여의도동 2-11     NS  노상 주차장     1
# 4  144561           한국통신(구)    양천구 목동 924-1     NS  노상 주차장     1
#
#            운영구분명          전화번호  총 주자면 유무료구분  ... 노상 주차장 관리그룹번호 기본 주차 요금  \
# 0  시간제 + 거주자 주차장           NaN      1     Y  ...  1.130510e+12    200.0
# 1  시간제 + 거주자 주차장           NaN      1     Y  ...  1.130510e+12    200.0
# 2  시간제 + 거주자 주차장   02-944-3025      1     Y  ...  1.130510e+12    200.0
# 3        시간제 주차장  02-2650-1436      1     Y  ...  1.156011e+12    500.0
# 4        시간제 주차장           NaN      1     Y  ...  1.147010e+12    250.0
#
#   기본 주차 시간(분 단위)  추가 단위 요금  추가 단위 시간(분 단위)  버스 기본 주차 요금  버스 기본 주차 시간(분 단위)  \
# ...
