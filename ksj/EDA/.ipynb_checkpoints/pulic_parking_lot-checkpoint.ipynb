# %% [markdown]
# # 서울시 공영주차장 안내 정보 데이터
# ## https://data.seoul.go.kr/dataList/OA-13122/S/1/datasetView.do

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/서울시 공영주차장 안내 정보.csv', encoding = 'cp949')
df.shape
# Out:
# (1155, 35)

# %%
# 광진구 데이터만 뽑기
kj_df = df[df['주소'].str.contains('광진구')]
kj_df.head()
# Out:
#      주차장코드            주차장명              주소 주차장 종류 주차장 종류명  운영구분    운영구분명  \
# 50  172178  자양유수지 공영주차장(구)   광진구 자양동 594-0     NW  노외 주차장     1  시간제 주차장
# 51  172184    동서울 노외주차장(구)   광진구 구의동 598-1     NW  노외 주차장     1  시간제 주차장
# 52  172198   구의1동 공영주차장(구)  광진구 구의동 243-78     NW  노외 주차장     1  시간제 주차장
# 53  172204      능동공영주차장(구)    광진구 능동 205-0     NW  노외 주차장     1  시간제 주차장
# 54  172215       화양동 공영(구)    광진구 화양동 63-2     NW  노외 주차장     1  시간제 주차장
#
#             전화번호  총 주자면 유무료구분  ... 노상 주차장 관리그룹번호 기본 주차 요금 기본 주차 시간(분 단위)  \
# 50  02-2049-4596    281     Y  ...           NaN    150.0            5.0
# 51           NaN     25     Y  ...           NaN    250.0            5.0
# 52  02-2049-4596    172     Y  ...           NaN    150.0            5.0
# 53  02-2049-4596     77     Y  ...           NaN    150.0            5.0
# 54           NaN     44     Y  ...           NaN    150.0            5.0
#
#     추가 단위 요금  추가 단위 시간(분 단위)  버스 기본 주차 요금  버스 기본 주차 시간(분 단위)  \
# ...

# %%
kj_df.shape

# 위 코드의 결과로 광진구에 있는 공영주차장은 총 26개 임을 알 수 있음
# Out:
# (26, 35)
